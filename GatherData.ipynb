# %%
import pandas as pd



#Read in a CSV

# %%
slcWeatherdata = pd.read_csv('SLCWeatherAsCSV.csv')
slcWeatherdata.head(50)

# %%
slcStormdata = pd.read_csv('storm_data_search_results.csv')
slcStormdata.head(5)
# Out:
#    EVENT_ID                                  CZ_NAME_STR BEGIN_LOCATION  \
# 0    611478          SALT LAKE AND TOOELE VALLEYS (ZONE)
# 1    611479  GREAT SALT LAKE DESERT AND MOUNTAINS (ZONE)
# 2    612555          WASATCH MOUNTAINS I-80 NORTH (ZONE)
# 3    612556       WASATCH MOUNTAINS SOUTH OF I-80 (ZONE)
# 4    612547          SALT LAKE AND TOOELE VALLEYS (ZONE)
#
#    BEGIN_DATE  BEGIN_TIME    EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  \
# 0  12/10/2015        1245     High Wind     60.00                          0
# 1  12/10/2015        1615     High Wind     58.00                          0
# 2  12/13/2015        2100  Winter Storm                                    0
# 3  12/13/2015        2100  Winter Storm                                    0
# 4  12/13/2015        2200  Winter Storm                                    0
#
#    INJURIES_DIRECT  ...  END_LOCATION    END_DATE END_TIME BEGIN_LAT  \
# 0                0  ...                12/10/2015     1715
# 1                0  ...                12/10/2015     1645
# 2                0  ...                12/15/2015     2000
# 3                0  ...                12/15/2015     2100
# 4                0  ...                12/15/2015     1900
#
#   BEGIN_LON  END_LAT END_LON  \
# 0
# 1
# 2
# 3
# 4
#
#                                      EVENT_NARRATIVE  \
# 0  Peak recorded wind gusts in the Salt Lake and ...
# 1  Maximum recorded wind gusts in the Great Salt ...
# 2  Storm total snowfall in in the northern Wasatc...
# 3  Storm total snowfall reports included 34 inche...
# 4  Most of the Salt Lake and Tooele Valleys recei...
#
#                                    EPISODE_NARRATIVE  ABSOLUTE_ROWNUMBER
# 0  Strong, gusty southerly winds developed ahead ...                   1
# 1  Strong, gusty southerly winds developed ahead ...                   2
# 2  A strong, slow moving winter storm crossed Uta...                   3
# 3  A strong, slow moving winter storm crossed Uta...                   4
# 4  A strong, slow moving winter storm crossed Uta...                   5
#
# [5 rows x 39 columns]

# %%
import requests
import json 

url = 'https://crashviewer.nhtsa.dot.gov/CrashAPI'
#endpoint = '/crashes/GetCaseList?states=1,51&fromYear=2014&toYear=2015&minNumOfVehicles=1&maxNumOfVehicles=6&format=json'
endpoint = '/crashes/GetCaseList?states=49&fromYear=2018&toYear=2021&minNumOfVehicles=1&maxNumOfVehicles=100&format=json'

# '.get' refers to the type of request: GET, POST, or many others but those two are most common
response = requests.get(url+endpoint) 

#format the json and load it into an object
json_data = json.loads(response.text)

#display the data
json_data

#save to the local file system
#with open('coins.json', 'w') as f:
#    f.write(json.dumps(json_data['data']))
#    f.close
